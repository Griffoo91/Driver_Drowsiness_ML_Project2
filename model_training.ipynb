# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout, Input, Flatten, Dense, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2024-02-25 20:48:03.994375: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-25 20:48:04.040930: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-25 20:48:04.040969: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-25 20:48:04.042323: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-25 20:48:04.050035: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-25 20:48:04.050557: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-25 20:48:05.073820: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
batchsize = 8

# %% [markdown]
# #training model with data data and splitting it into
# training and validation

# %%
train_datagen = ImageDataGenerator(rescale=1./255, rotation_range = 0.2, shear_range = 0.2, zoom_range = 0.2,width_shift_range = 0.2, height_shift_range = 0.2, validation_split = 0.2)
train_data = train_datagen.flow_from_directory(r'/home/blackson/Desktop/Projects/Machine_Learning/Driver_Drowsiness_ML_Project2/PreparedData/', target_size =(80,80), batch_size = batchsize, class_mode = 'categorical', subset = 'training')
validation_data = train_datagen.flow_from_directory(r'/home/blackson/Desktop/Projects/Machine_Learning/Driver_Drowsiness_ML_Project2/PreparedData/train/', target_size = (80,80), batch_size = batchsize, class_mode = 'categorical', subset = 'validation')
# Out:
# Found 67920 images belonging to 2 classes.
# Found 16084 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_data = test_datagen.flow_from_directory(r'/home/blackson/Desktop/Projects/Machine_Learning/Driver_Drowsiness_ML_Project2/PreparedData/test', target_size =(80,80), batch_size = batchsize, class_mode = 'categorical')
# Out:
# Found 4474 images belonging to 2 classes.

# %%
bmodel = InceptionV3(include_top = False, weights = 'imagenet', input_tensor = Input(shape = (80,80,3), batch_size = 8))
hmodel = bmodel.output
hmodel = Flatten()(hmodel)
hmodel = Dense(64, activation = 'relu')(hmodel)
hmodel = Dropout(0.5)(hmodel)
hmodel = Dense(2, activation = 'softmax')(hmodel)

model = Model(inputs = bmodel.input, outputs = hmodel)
for layer in bmodel.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(8, 80, 80, 3)]             0         []
#
#  conv2d_188 (Conv2D)         (8, 39, 39, 32)              864       ['input_3[0][0]']
#
#  batch_normalization_188 (B  (8, 39, 39, 32)              96        ['conv2d_188[0][0]']
#  atchNormalization)
#
#  activation_188 (Activation  (8, 39, 39, 32)              0         ['batch_normalization_188[0][0
#  )                                                                  ]']
#
#  conv2d_189 (Conv2D)         (8, 37, 37, 32)              9216      ['activation_188[0][0]']
#
#  batch_normalization_189 (B  (8, 37, 37, 32)              96        ['conv2d_189[0][0]']
#  atchNormalization)
#
#  activation_189 (Activation  (8, 37, 37, 32)              0         ['batch_normalization_189[0][0
#  )                                                                  ]']
#
#  conv2d_190 (Conv2D)         (8, 37, 37, 64)              18432     ['activation_189[0][0]']
#
#  batch_normalization_190 (B  (8, 37, 37, 64)              192       ['conv2d_190[0][0]']
#  atchNormalization)
#
#  activation_190 (Activation  (8, 37, 37, 64)              0         ['batch_normalization_190[0][0
#  )                                                                  ]']
#
#  max_pooling2d_8 (MaxPoolin  (8, 18, 18, 64)              0         ['activation_190[0][0]']
#  g2D)
#
#  conv2d_191 (Conv2D)         (8, 18, 18, 80)              5120      ['max_pooling2d_8[0][0]']
#
#  batch_normalization_191 (B  (8, 18, 18, 80)              240       ['conv2d_191[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (8, 18, 18, 80)              0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  conv2d_192 (Conv2D)         (8, 16, 16, 192)             138240    ['activation_191[0][0]']
#
#  batch_normalization_192 (B  (8, 16, 16, 192)             576       ['conv2d_192[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (8, 16, 16, 192)             0         ['batch_normalization_192[0][0
#  )                                                                  ]']
#
#  max_pooling2d_9 (MaxPoolin  (8, 7, 7, 192)               0         ['activation_192[0][0]']
#  g2D)
#
#  conv2d_196 (Conv2D)         (8, 7, 7, 64)                12288     ['max_pooling2d_9[0][0]']
#
#  batch_normalization_196 (B  (8, 7, 7, 64)                192       ['conv2d_196[0][0]']
#  atchNormalization)
#
#  activation_196 (Activation  (8, 7, 7, 64)                0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  conv2d_194 (Conv2D)         (8, 7, 7, 48)                9216      ['max_pooling2d_9[0][0]']
#
#  conv2d_197 (Conv2D)         (8, 7, 7, 96)                55296     ['activation_196[0][0]']
#
#  batch_normalization_194 (B  (8, 7, 7, 48)                144       ['conv2d_194[0][0]']
#  atchNormalization)
#
#  batch_normalization_197 (B  (8, 7, 7, 96)                288       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  activation_194 (Activation  (8, 7, 7, 48)                0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  activation_197 (Activation  (8, 7, 7, 96)                0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  average_pooling2d_18 (Aver  (8, 7, 7, 192)               0         ['max_pooling2d_9[0][0]']
#  agePooling2D)
#
#  conv2d_193 (Conv2D)         (8, 7, 7, 64)                12288     ['max_pooling2d_9[0][0]']
#
#  conv2d_195 (Conv2D)         (8, 7, 7, 64)                76800     ['activation_194[0][0]']
#
#  conv2d_198 (Conv2D)         (8, 7, 7, 96)                82944     ['activation_197[0][0]']
#
#  conv2d_199 (Conv2D)         (8, 7, 7, 32)                6144      ['average_pooling2d_18[0][0]']
#
#  batch_normalization_193 (B  (8, 7, 7, 64)                192       ['conv2d_193[0][0]']
#  atchNormalization)
#
#  batch_normalization_195 (B  (8, 7, 7, 64)                192       ['conv2d_195[0][0]']
#  atchNormalization)
#
#  batch_normalization_198 (B  (8, 7, 7, 96)                288       ['conv2d_198[0][0]']
#  atchNormalization)
#
#  batch_normalization_199 (B  (8, 7, 7, 32)                96        ['conv2d_199[0][0]']
#  atchNormalization)
#
#  activation_193 (Activation  (8, 7, 7, 64)                0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  activation_195 (Activation  (8, 7, 7, 64)                0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  activation_198 (Activation  (8, 7, 7, 96)                0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  activation_199 (Activation  (8, 7, 7, 32)                0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (8, 7, 7, 256)               0         ['activation_193[0][0]',
#                                                                      'activation_195[0][0]',
#                                                                      'activation_198[0][0]',
#                                                                      'activation_199[0][0]']
#
#  conv2d_203 (Conv2D)         (8, 7, 7, 64)                16384     ['mixed0[0][0]']
#
#  batch_normalization_203 (B  (8, 7, 7, 64)                192       ['conv2d_203[0][0]']
#  atchNormalization)
#
#  activation_203 (Activation  (8, 7, 7, 64)                0         ['batch_normalization_203[0][0
#  )                                                                  ]']
#
#  conv2d_201 (Conv2D)         (8, 7, 7, 48)                12288     ['mixed0[0][0]']
#
#  conv2d_204 (Conv2D)         (8, 7, 7, 96)                55296     ['activation_203[0][0]']
#
#  batch_normalization_201 (B  (8, 7, 7, 48)                144       ['conv2d_201[0][0]']
#  atchNormalization)
#
#  batch_normalization_204 (B  (8, 7, 7, 96)                288       ['conv2d_204[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (8, 7, 7, 48)                0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  activation_204 (Activation  (8, 7, 7, 96)                0         ['batch_normalization_204[0][0
#  )                                                                  ]']
#
#  average_pooling2d_19 (Aver  (8, 7, 7, 256)               0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_200 (Conv2D)         (8, 7, 7, 64)                16384     ['mixed0[0][0]']
#
#  conv2d_202 (Conv2D)         (8, 7, 7, 64)                76800     ['activation_201[0][0]']
#
#  conv2d_205 (Conv2D)         (8, 7, 7, 96)                82944     ['activation_204[0][0]']
#
#  conv2d_206 (Conv2D)         (8, 7, 7, 64)                16384     ['average_pooling2d_19[0][0]']
#
#  batch_normalization_200 (B  (8, 7, 7, 64)                192       ['conv2d_200[0][0]']
#  atchNormalization)
#
#  batch_normalization_202 (B  (8, 7, 7, 64)                192       ['conv2d_202[0][0]']
#  atchNormalization)
#
#  batch_normalization_205 (B  (8, 7, 7, 96)                288       ['conv2d_205[0][0]']
#  atchNormalization)
#
#  batch_normalization_206 (B  (8, 7, 7, 64)                192       ['conv2d_206[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (8, 7, 7, 64)                0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  activation_202 (Activation  (8, 7, 7, 64)                0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  activation_205 (Activation  (8, 7, 7, 96)                0         ['batch_normalization_205[0][0
#  )                                                                  ]']
#
#  activation_206 (Activation  (8, 7, 7, 64)                0         ['batch_normalization_206[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (8, 7, 7, 288)               0         ['activation_200[0][0]',
#                                                                      'activation_202[0][0]',
#                                                                      'activation_205[0][0]',
#                                                                      'activation_206[0][0]']
#
#  conv2d_210 (Conv2D)         (8, 7, 7, 64)                18432     ['mixed1[0][0]']
#
#  batch_normalization_210 (B  (8, 7, 7, 64)                192       ['conv2d_210[0][0]']
#  atchNormalization)
#
#  activation_210 (Activation  (8, 7, 7, 64)                0         ['batch_normalization_210[0][0
#  )                                                                  ]']
#
#  conv2d_208 (Conv2D)         (8, 7, 7, 48)                13824     ['mixed1[0][0]']
#
#  conv2d_211 (Conv2D)         (8, 7, 7, 96)                55296     ['activation_210[0][0]']
#
#  batch_normalization_208 (B  (8, 7, 7, 48)                144       ['conv2d_208[0][0]']
#  atchNormalization)
#
#  batch_normalization_211 (B  (8, 7, 7, 96)                288       ['conv2d_211[0][0]']
#  atchNormalization)
#
#  activation_208 (Activation  (8, 7, 7, 48)                0         ['batch_normalization_208[0][0
#  )                                                                  ]']
#
#  activation_211 (Activation  (8, 7, 7, 96)                0         ['batch_normalization_211[0][0
#  )                                                                  ]']
#
#  average_pooling2d_20 (Aver  (8, 7, 7, 288)               0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_207 (Conv2D)         (8, 7, 7, 64)                18432     ['mixed1[0][0]']
#
#  conv2d_209 (Conv2D)         (8, 7, 7, 64)                76800     ['activation_208[0][0]']
#
#  conv2d_212 (Conv2D)         (8, 7, 7, 96)                82944     ['activation_211[0][0]']
#
#  conv2d_213 (Conv2D)         (8, 7, 7, 64)                18432     ['average_pooling2d_20[0][0]']
#
#  batch_normalization_207 (B  (8, 7, 7, 64)                192       ['conv2d_207[0][0]']
#  atchNormalization)
#
#  batch_normalization_209 (B  (8, 7, 7, 64)                192       ['conv2d_209[0][0]']
#  atchNormalization)
#
#  batch_normalization_212 (B  (8, 7, 7, 96)                288       ['conv2d_212[0][0]']
#  atchNormalization)
#
#  batch_normalization_213 (B  (8, 7, 7, 64)                192       ['conv2d_213[0][0]']
#  atchNormalization)
#
#  activation_207 (Activation  (8, 7, 7, 64)                0         ['batch_normalization_207[0][0
#  )                                                                  ]']
#
#  activation_209 (Activation  (8, 7, 7, 64)                0         ['batch_normalization_209[0][0
#  )                                                                  ]']
#
#  activation_212 (Activation  (8, 7, 7, 96)                0         ['batch_normalization_212[0][0
#  )                                                                  ]']
#
#  activation_213 (Activation  (8, 7, 7, 64)                0         ['batch_normalization_213[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (8, 7, 7, 288)               0         ['activation_207[0][0]',
#                                                                      'activation_209[0][0]',
#                                                                      'activation_212[0][0]',
#                                                                      'activation_213[0][0]']
#
#  conv2d_215 (Conv2D)         (8, 7, 7, 64)                18432     ['mixed2[0][0]']
#
#  batch_normalization_215 (B  (8, 7, 7, 64)                192       ['conv2d_215[0][0]']
#  atchNormalization)
#
#  activation_215 (Activation  (8, 7, 7, 64)                0         ['batch_normalization_215[0][0
#  )                                                                  ]']
#
#  conv2d_216 (Conv2D)         (8, 7, 7, 96)                55296     ['activation_215[0][0]']
#
#  batch_normalization_216 (B  (8, 7, 7, 96)                288       ['conv2d_216[0][0]']
#  atchNormalization)
#
#  activation_216 (Activation  (8, 7, 7, 96)                0         ['batch_normalization_216[0][0
#  )                                                                  ]']
#
#  conv2d_214 (Conv2D)         (8, 3, 3, 384)               995328    ['mixed2[0][0]']
#
#  conv2d_217 (Conv2D)         (8, 3, 3, 96)                82944     ['activation_216[0][0]']
#
#  batch_normalization_214 (B  (8, 3, 3, 384)               1152      ['conv2d_214[0][0]']
#  atchNormalization)
#
#  batch_normalization_217 (B  (8, 3, 3, 96)                288       ['conv2d_217[0][0]']
#  atchNormalization)
#
#  activation_214 (Activation  (8, 3, 3, 384)               0         ['batch_normalization_214[0][0
#  )                                                                  ]']
#
#  activation_217 (Activation  (8, 3, 3, 96)                0         ['batch_normalization_217[0][0
#  )                                                                  ]']
#
#  max_pooling2d_10 (MaxPooli  (8, 3, 3, 288)               0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (8, 3, 3, 768)               0         ['activation_214[0][0]',
#                                                                      'activation_217[0][0]',
#                                                                      'max_pooling2d_10[0][0]']
#
#  conv2d_222 (Conv2D)         (8, 3, 3, 128)               98304     ['mixed3[0][0]']
#
#  batch_normalization_222 (B  (8, 3, 3, 128)               384       ['conv2d_222[0][0]']
#  atchNormalization)
#
#  activation_222 (Activation  (8, 3, 3, 128)               0         ['batch_normalization_222[0][0
#  )                                                                  ]']
#
#  conv2d_223 (Conv2D)         (8, 3, 3, 128)               114688    ['activation_222[0][0]']
#
#  batch_normalization_223 (B  (8, 3, 3, 128)               384       ['conv2d_223[0][0]']
#  atchNormalization)
#
#  activation_223 (Activation  (8, 3, 3, 128)               0         ['batch_normalization_223[0][0
#  )                                                                  ]']
#
#  conv2d_219 (Conv2D)         (8, 3, 3, 128)               98304     ['mixed3[0][0]']
#
#  conv2d_224 (Conv2D)         (8, 3, 3, 128)               114688    ['activation_223[0][0]']
#
#  batch_normalization_219 (B  (8, 3, 3, 128)               384       ['conv2d_219[0][0]']
#  atchNormalization)
#
#  batch_normalization_224 (B  (8, 3, 3, 128)               384       ['conv2d_224[0][0]']
#  atchNormalization)
#
#  activation_219 (Activation  (8, 3, 3, 128)               0         ['batch_normalization_219[0][0
#  )                                                                  ]']
#
#  activation_224 (Activation  (8, 3, 3, 128)               0         ['batch_normalization_224[0][0
#  )                                                                  ]']
#
#  conv2d_220 (Conv2D)         (8, 3, 3, 128)               114688    ['activation_219[0][0]']
#
#  conv2d_225 (Conv2D)         (8, 3, 3, 128)               114688    ['activation_224[0][0]']
#
#  batch_normalization_220 (B  (8, 3, 3, 128)               384       ['conv2d_220[0][0]']
#  atchNormalization)
#
#  batch_normalization_225 (B  (8, 3, 3, 128)               384       ['conv2d_225[0][0]']
#  atchNormalization)
#
#  activation_220 (Activation  (8, 3, 3, 128)               0         ['batch_normalization_220[0][0
#  )                                                                  ]']
#
#  activation_225 (Activation  (8, 3, 3, 128)               0         ['batch_normalization_225[0][0
#  )                                                                  ]']
#
#  average_pooling2d_21 (Aver  (8, 3, 3, 768)               0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_218 (Conv2D)         (8, 3, 3, 192)               147456    ['mixed3[0][0]']
#
#  conv2d_221 (Conv2D)         (8, 3, 3, 192)               172032    ['activation_220[0][0]']
#
#  conv2d_226 (Conv2D)         (8, 3, 3, 192)               172032    ['activation_225[0][0]']
#
#  conv2d_227 (Conv2D)         (8, 3, 3, 192)               147456    ['average_pooling2d_21[0][0]']
#
#  batch_normalization_218 (B  (8, 3, 3, 192)               576       ['conv2d_218[0][0]']
#  atchNormalization)
#
#  batch_normalization_221 (B  (8, 3, 3, 192)               576       ['conv2d_221[0][0]']
#  atchNormalization)
#
#  batch_normalization_226 (B  (8, 3, 3, 192)               576       ['conv2d_226[0][0]']
#  atchNormalization)
#
#  batch_normalization_227 (B  (8, 3, 3, 192)               576       ['conv2d_227[0][0]']
#  atchNormalization)
#
#  activation_218 (Activation  (8, 3, 3, 192)               0         ['batch_normalization_218[0][0
#  )                                                                  ]']
#
#  activation_221 (Activation  (8, 3, 3, 192)               0         ['batch_normalization_221[0][0
#  )                                                                  ]']
#
#  activation_226 (Activation  (8, 3, 3, 192)               0         ['batch_normalization_226[0][0
#  )                                                                  ]']
#
#  activation_227 (Activation  (8, 3, 3, 192)               0         ['batch_normalization_227[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (8, 3, 3, 768)               0         ['activation_218[0][0]',
#                                                                      'activation_221[0][0]',
#                                                                      'activation_226[0][0]',
#                                                                      'activation_227[0][0]']
#
#  conv2d_232 (Conv2D)         (8, 3, 3, 160)               122880    ['mixed4[0][0]']
#
#  batch_normalization_232 (B  (8, 3, 3, 160)               480       ['conv2d_232[0][0]']
#  atchNormalization)
#
#  activation_232 (Activation  (8, 3, 3, 160)               0         ['batch_normalization_232[0][0
#  )                                                                  ]']
#
#  conv2d_233 (Conv2D)         (8, 3, 3, 160)               179200    ['activation_232[0][0]']
#
#  batch_normalization_233 (B  (8, 3, 3, 160)               480       ['conv2d_233[0][0]']
#  atchNormalization)
#
#  activation_233 (Activation  (8, 3, 3, 160)               0         ['batch_normalization_233[0][0
#  )                                                                  ]']
#
#  conv2d_229 (Conv2D)         (8, 3, 3, 160)               122880    ['mixed4[0][0]']
#
#  conv2d_234 (Conv2D)         (8, 3, 3, 160)               179200    ['activation_233[0][0]']
#
#  batch_normalization_229 (B  (8, 3, 3, 160)               480       ['conv2d_229[0][0]']
#  atchNormalization)
#
#  batch_normalization_234 (B  (8, 3, 3, 160)               480       ['conv2d_234[0][0]']
#  atchNormalization)
#
#  activation_229 (Activation  (8, 3, 3, 160)               0         ['batch_normalization_229[0][0
#  )                                                                  ]']
#
#  activation_234 (Activation  (8, 3, 3, 160)               0         ['batch_normalization_234[0][0
#  )                                                                  ]']
#
#  conv2d_230 (Conv2D)         (8, 3, 3, 160)               179200    ['activation_229[0][0]']
#
#  conv2d_235 (Conv2D)         (8, 3, 3, 160)               179200    ['activation_234[0][0]']
#
#  batch_normalization_230 (B  (8, 3, 3, 160)               480       ['conv2d_230[0][0]']
#  atchNormalization)
#
#  batch_normalization_235 (B  (8, 3, 3, 160)               480       ['conv2d_235[0][0]']
#  atchNormalization)
#
#  activation_230 (Activation  (8, 3, 3, 160)               0         ['batch_normalization_230[0][0
#  )                                                                  ]']
#
#  activation_235 (Activation  (8, 3, 3, 160)               0         ['batch_normalization_235[0][0
#  )                                                                  ]']
#
#  average_pooling2d_22 (Aver  (8, 3, 3, 768)               0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_228 (Conv2D)         (8, 3, 3, 192)               147456    ['mixed4[0][0]']
#
#  conv2d_231 (Conv2D)         (8, 3, 3, 192)               215040    ['activation_230[0][0]']
#
#  conv2d_236 (Conv2D)         (8, 3, 3, 192)               215040    ['activation_235[0][0]']
#
#  conv2d_237 (Conv2D)         (8, 3, 3, 192)               147456    ['average_pooling2d_22[0][0]']
#
#  batch_normalization_228 (B  (8, 3, 3, 192)               576       ['conv2d_228[0][0]']
#  atchNormalization)
#
#  batch_normalization_231 (B  (8, 3, 3, 192)               576       ['conv2d_231[0][0]']
#  atchNormalization)
#
#  batch_normalization_236 (B  (8, 3, 3, 192)               576       ['conv2d_236[0][0]']
#  atchNormalization)
#
#  batch_normalization_237 (B  (8, 3, 3, 192)               576       ['conv2d_237[0][0]']
#  atchNormalization)
#
#  activation_228 (Activation  (8, 3, 3, 192)               0         ['batch_normalization_228[0][0
#  )                                                                  ]']
#
#  activation_231 (Activation  (8, 3, 3, 192)               0         ['batch_normalization_231[0][0
#  )                                                                  ]']
#
#  activation_236 (Activation  (8, 3, 3, 192)               0         ['batch_normalization_236[0][0
#  )                                                                  ]']
#
#  activation_237 (Activation  (8, 3, 3, 192)               0         ['batch_normalization_237[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (8, 3, 3, 768)               0         ['activation_228[0][0]',
#                                                                      'activation_231[0][0]',
#                                                                      'activation_236[0][0]',
#                                                                      'activation_237[0][0]']
#
#  conv2d_242 (Conv2D)         (8, 3, 3, 160)               122880    ['mixed5[0][0]']
#
#  batch_normalization_242 (B  (8, 3, 3, 160)               480       ['conv2d_242[0][0]']
#  atchNormalization)
#
#  activation_242 (Activation  (8, 3, 3, 160)               0         ['batch_normalization_242[0][0
#  )                                                                  ]']
#
#  conv2d_243 (Conv2D)         (8, 3, 3, 160)               179200    ['activation_242[0][0]']
#
#  batch_normalization_243 (B  (8, 3, 3, 160)               480       ['conv2d_243[0][0]']
#  atchNormalization)
#
#  activation_243 (Activation  (8, 3, 3, 160)               0         ['batch_normalization_243[0][0
#  )                                                                  ]']
#
#  conv2d_239 (Conv2D)         (8, 3, 3, 160)               122880    ['mixed5[0][0]']
#
#  conv2d_244 (Conv2D)         (8, 3, 3, 160)               179200    ['activation_243[0][0]']
#
#  batch_normalization_239 (B  (8, 3, 3, 160)               480       ['conv2d_239[0][0]']
#  atchNormalization)
#
#  batch_normalization_244 (B  (8, 3, 3, 160)               480       ['conv2d_244[0][0]']
#  atchNormalization)
#
# ...
#  )                                                                  ]']
#
#  conv2d_266 (Conv2D)         (8, 1, 1, 384)               442368    ['activation_265[0][0]']
#
#  conv2d_267 (Conv2D)         (8, 1, 1, 384)               442368    ['activation_265[0][0]']
#
#  conv2d_270 (Conv2D)         (8, 1, 1, 384)               442368    ['activation_269[0][0]']
#
#  conv2d_271 (Conv2D)         (8, 1, 1, 384)               442368    ['activation_269[0][0]']
#
#  average_pooling2d_25 (Aver  (8, 1, 1, 1280)              0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_264 (Conv2D)         (8, 1, 1, 320)               409600    ['mixed8[0][0]']
#
#  batch_normalization_266 (B  (8, 1, 1, 384)               1152      ['conv2d_266[0][0]']
#  atchNormalization)
#
#  batch_normalization_267 (B  (8, 1, 1, 384)               1152      ['conv2d_267[0][0]']
#  atchNormalization)
#
#  batch_normalization_270 (B  (8, 1, 1, 384)               1152      ['conv2d_270[0][0]']
#  atchNormalization)
#
#  batch_normalization_271 (B  (8, 1, 1, 384)               1152      ['conv2d_271[0][0]']
#  atchNormalization)
#
#  conv2d_272 (Conv2D)         (8, 1, 1, 192)               245760    ['average_pooling2d_25[0][0]']
#
#  batch_normalization_264 (B  (8, 1, 1, 320)               960       ['conv2d_264[0][0]']
#  atchNormalization)
#
#  activation_266 (Activation  (8, 1, 1, 384)               0         ['batch_normalization_266[0][0
#  )                                                                  ]']
#
#  activation_267 (Activation  (8, 1, 1, 384)               0         ['batch_normalization_267[0][0
#  )                                                                  ]']
#
#  activation_270 (Activation  (8, 1, 1, 384)               0         ['batch_normalization_270[0][0
#  )                                                                  ]']
#
#  activation_271 (Activation  (8, 1, 1, 384)               0         ['batch_normalization_271[0][0
#  )                                                                  ]']
#
#  batch_normalization_272 (B  (8, 1, 1, 192)               576       ['conv2d_272[0][0]']
#  atchNormalization)
#
#  activation_264 (Activation  (8, 1, 1, 320)               0         ['batch_normalization_264[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (8, 1, 1, 768)               0         ['activation_266[0][0]',
#                                                                      'activation_267[0][0]']
#
#  concatenate_4 (Concatenate  (8, 1, 1, 768)               0         ['activation_270[0][0]',
#  )                                                                   'activation_271[0][0]']
#
#  activation_272 (Activation  (8, 1, 1, 192)               0         ['batch_normalization_272[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (8, 1, 1, 2048)              0         ['activation_264[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_4[0][0]',
#                                                                      'activation_272[0][0]']
#
#  conv2d_277 (Conv2D)         (8, 1, 1, 448)               917504    ['mixed9[0][0]']
#
#  batch_normalization_277 (B  (8, 1, 1, 448)               1344      ['conv2d_277[0][0]']
#  atchNormalization)
#
#  activation_277 (Activation  (8, 1, 1, 448)               0         ['batch_normalization_277[0][0
#  )                                                                  ]']
#
#  conv2d_274 (Conv2D)         (8, 1, 1, 384)               786432    ['mixed9[0][0]']
#
#  conv2d_278 (Conv2D)         (8, 1, 1, 384)               1548288   ['activation_277[0][0]']
#
#  batch_normalization_274 (B  (8, 1, 1, 384)               1152      ['conv2d_274[0][0]']
#  atchNormalization)
#
#  batch_normalization_278 (B  (8, 1, 1, 384)               1152      ['conv2d_278[0][0]']
#  atchNormalization)
#
#  activation_274 (Activation  (8, 1, 1, 384)               0         ['batch_normalization_274[0][0
#  )                                                                  ]']
#
#  activation_278 (Activation  (8, 1, 1, 384)               0         ['batch_normalization_278[0][0
#  )                                                                  ]']
#
#  conv2d_275 (Conv2D)         (8, 1, 1, 384)               442368    ['activation_274[0][0]']
#
#  conv2d_276 (Conv2D)         (8, 1, 1, 384)               442368    ['activation_274[0][0]']
#
#  conv2d_279 (Conv2D)         (8, 1, 1, 384)               442368    ['activation_278[0][0]']
#
#  conv2d_280 (Conv2D)         (8, 1, 1, 384)               442368    ['activation_278[0][0]']
#
#  average_pooling2d_26 (Aver  (8, 1, 1, 2048)              0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_273 (Conv2D)         (8, 1, 1, 320)               655360    ['mixed9[0][0]']
#
#  batch_normalization_275 (B  (8, 1, 1, 384)               1152      ['conv2d_275[0][0]']
#  atchNormalization)
#
#  batch_normalization_276 (B  (8, 1, 1, 384)               1152      ['conv2d_276[0][0]']
#  atchNormalization)
#
#  batch_normalization_279 (B  (8, 1, 1, 384)               1152      ['conv2d_279[0][0]']
#  atchNormalization)
#
#  batch_normalization_280 (B  (8, 1, 1, 384)               1152      ['conv2d_280[0][0]']
#  atchNormalization)
#
#  conv2d_281 (Conv2D)         (8, 1, 1, 192)               393216    ['average_pooling2d_26[0][0]']
#
#  batch_normalization_273 (B  (8, 1, 1, 320)               960       ['conv2d_273[0][0]']
#  atchNormalization)
#
#  activation_275 (Activation  (8, 1, 1, 384)               0         ['batch_normalization_275[0][0
#  )                                                                  ]']
#
#  activation_276 (Activation  (8, 1, 1, 384)               0         ['batch_normalization_276[0][0
#  )                                                                  ]']
#
#  activation_279 (Activation  (8, 1, 1, 384)               0         ['batch_normalization_279[0][0
#  )                                                                  ]']
#
#  activation_280 (Activation  (8, 1, 1, 384)               0         ['batch_normalization_280[0][0
#  )                                                                  ]']
#
#  batch_normalization_281 (B  (8, 1, 1, 192)               576       ['conv2d_281[0][0]']
#  atchNormalization)
#
#  activation_273 (Activation  (8, 1, 1, 320)               0         ['batch_normalization_273[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (8, 1, 1, 768)               0         ['activation_275[0][0]',
#                                                                      'activation_276[0][0]']
#
#  concatenate_5 (Concatenate  (8, 1, 1, 768)               0         ['activation_279[0][0]',
#  )                                                                   'activation_280[0][0]']
#
#  activation_281 (Activation  (8, 1, 1, 192)               0         ['batch_normalization_281[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (8, 1, 1, 2048)              0         ['activation_273[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_5[0][0]',
#                                                                      'activation_281[0][0]']
#
#  flatten_2 (Flatten)         (8, 2048)                    0         ['mixed10[0][0]']
#
#  dense_4 (Dense)             (8, 64)                      131136    ['flatten_2[0][0]']
#
#  dropout_2 (Dropout)         (8, 64)                      0         ['dense_4[0][0]']
#
#  dense_5 (Dense)             (8, 2)                       130       ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 21934050 (83.67 MB)
# Trainable params: 131266 (512.76 KB)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
checkpoint = ModelCheckpoint(r'/home/blackson/Desktop/Projects/Machine_Learning/Driver_Drowsiness_ML_Project/models/', monitor = 'val_loss', save_best_only = True, verbose = 3)
earlystop = EarlyStopping(monitor = 'val_loss', patience = 7, verbose = 3, restore_best_weights = True)
learning_rate = ReduceLROnPlateau(monitor = 'val_loss', patience = 3, verbose = 3)

# %%
model.compile(optimizer = Adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.fit_generator(train_data, steps_per_epoch = train_data.samples//batchsize, validation_data = validation_data, validation_steps = validation_data.sample//batchsize)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 model.compile(optimizer = Adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])
#       2 model.fit_generator(train_data, steps_per_epoch = train_data.samples//batchsize, validation_data = validation_data, validation_steps = validation_data.sample//batchsize)
#
# File ~/.local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.local/lib/python3.11/site-packages/keras/src/optimizers/__init__.py:327, in get(identifier, **kwargs)
#     322     return get(
#     323         config,
#     324         use_legacy_optimizer=use_legacy_optimizer,
#     325     )
#     326 else:
# --> 327     raise ValueError(
#     328         f"Could not interpret optimizer identifier: {identifier}"
#     329     )
#
# ValueError: Could not interpret optimizer identifier: <class 'keras.src.optimizers.adam.Adam'>

# %%
# model evaluation

# %%
acc_tr, loss_tr = model.evaluate_generator(train_data) # evaluation of accuracy and loss of train data
print(acc_tr)
print(loss_tr)

# %%
acc_vr, loss_vr = model.evaluate_generator(validation_data) # evaluation of accuracy and loss of validation data
print(acc_vr)
print(loss_vr)

# %%
acc_test, loss_test = model.evaluate_generator(test_data) # evaluation of accuracy and loss of test  data
print(acc_test)
print(loss_test)
